# %%
import pandas as pd
df = pd.read_csv('AST_Data/combined.csv')
df
# Out:
#                                    class_name  \
# 0     ApplicationInsightsForK8sHostingStartup
# 1                   CGroupContainerIdProvider
# 2                FileBasedContainerIdProvider
# 3                FileBasedContainerIdProvider
# 4                             CGroupV1Matcher
# ...                                       ...
# 1857          OpenApiReferenceValidationTests
# 1858                         InheritanceTests
# 1859                         InheritanceTests
# 1860                    OpenApiWorkspaceTests
# 1861                    OpenApiWorkspaceTests
#
#                                               class_ast  \
# 0     \t9 ClassDeclaration\n\t\t9 BaseList\n\t\t\t9 ...
# 1     \t7 ClassDeclaration\n\t\t7 BaseList\n\t\t\t7 ...
# 2     \t9 ClassDeclaration\n\t\t9 BaseList\n\t\t\t9 ...
# 3     \t9 ClassDeclaration\n\t\t9 BaseList\n\t\t\t9 ...
# 4     \t6 ClassDeclaration\n\t\t6 BaseList\n\t\t\t6 ...
# ...                                                 ...
# 1857  \t156 ClassDeclaration\n\t\t156 TypeParameterL...
# 1858  \t13 ClassDeclaration\n\t\t15 MethodDeclaratio...
# 1859  \t69 ClassDeclaration\n\t\t69 BaseList\n\t\t\t...
# 1860  \t15 ClassDeclaration\n\t\t17 MethodDeclaratio...
# 1861  \t222 ClassDeclaration\n\t\t224 MethodDeclarat...
#
#                                            parsed_smell  \
# 0     \n\t9 ClassDeclaration\n\t\t9 BaseList\n\t\t\t...
# 1     \n\t\t10 FieldDeclaration\n\t\t\t10 VariableDe...
# 2     \n\t\t16 ConstructorDeclaration\n\t\t\t16 Para...
# 3     \n\t\t\t\t\t\t48 LocalDeclarationStatement\n\t...
# 4     \n\t\t14 MethodDeclaration\n\t\t\t14 Predefine...
# ...                                                 ...
# 1857                                                NaN
# 1858                                                NaN
# 1859                                                NaN
# 1860                                                NaN
# 1861                                                NaN
#
#                                parsed_smell_identifiers     message
# 0     \n\t9 ClassDeclaration\n\t\t9 BaseList\n\t\t\t...      Rename
# 1     \n\t\t10 FieldDeclaration\n\t\t\t10 VariableDe...      Remove
# 2     \n\t\t16 ConstructorDeclaration\n\t\t\t16 Para...  Adjustment
# 3     \n\t\t\t\t\t\t48 LocalDeclarationStatement\n\t...    Refactor
# 4     \n\t\t14 MethodDeclaration\n\t\t\t14 Predefine...      Rename
# ...                                                 ...         ...
# 1857                                                NaN    Refactor
# 1858  \n\t\t\t\t66 ExpressionStatement\n\t\t\t\t\t66...    Refactor
# 1859                                                NaN    Refactor
# 1860  \n\t\t153 MethodDeclaration\n\t\t\t153 Predefi...    Refactor
# 1861                                                NaN    Refactor
#
# [1862 rows x 5 columns]

# %%
import pandas as pd

# Read the combined.csv file
df = pd.read_csv('AST_Data/combined.csv')

# Select only the specified columns
df_selected = df[['parsed_smell', 'parsed_smell_identifiers', 'message']]

# Drop rows with NaN values in the specified columns
df_dropped = df_selected.dropna(subset=['parsed_smell', 'parsed_smell_identifiers', 'message'])

# Save the modified DataFrame to a new CSV file
df_dropped.to_csv('AST_Data/temp/train-data.csv', index=False)

# Read the train-data.csv file
df = pd.read_csv('AST_Data/temp/train-data.csv')
df
# Out:
#                                            parsed_smell  \
# 0     \n\t9 ClassDeclaration\n\t\t9 BaseList\n\t\t\t...
# 1     \n\t\t10 FieldDeclaration\n\t\t\t10 VariableDe...
# 2     \n\t\t16 ConstructorDeclaration\n\t\t\t16 Para...
# 3     \n\t\t\t\t\t\t48 LocalDeclarationStatement\n\t...
# 4     \n\t\t14 MethodDeclaration\n\t\t\t14 Predefine...
# ...                                                 ...
# 1193  \n\t\t34 FieldDeclaration\n\t\t\t34 VariableDe...
# 1194  \n\t\t17 FieldDeclaration\n\t\t\t17 VariableDe...
# 1195  \n\t\t30 FieldDeclaration\n\t\t\t30 VariableDe...
# 1196  \n\t\t17 PropertyDeclaration\n\t\t\t17 Identif...
# 1197  \n\t\t45 PropertyDeclaration\n\t\t\t45 Identif...
#
#                                parsed_smell_identifiers     message
# 0     \n\t9 ClassDeclaration\n\t\t9 BaseList\n\t\t\t...      Rename
# 1     \n\t\t10 FieldDeclaration\n\t\t\t10 VariableDe...      Remove
# 2     \n\t\t16 ConstructorDeclaration\n\t\t\t16 Para...  Adjustment
# 3     \n\t\t\t\t\t\t48 LocalDeclarationStatement\n\t...    Refactor
# 4     \n\t\t14 MethodDeclaration\n\t\t\t14 Predefine...      Rename
# ...                                                 ...         ...
# 1193  \n\t\t34 FieldDeclaration\n\t\t\t34 VariableDe...    Refactor
# 1194  \n\t\t17 FieldDeclaration\n\t\t\t17 VariableDe...    Refactor
# 1195  \n\t\t30 FieldDeclaration\n\t\t\t30 VariableDe...    Refactor
# 1196  \n\t\t17 PropertyDeclaration\n\t\t\t17 Identif...    Refactor
# 1197  \n\t\t45 PropertyDeclaration\n\t\t\t45 Identif...    Refactor
#
# [1198 rows x 3 columns]

# %%
import csv

# Set the field size limit to a specific value
csv.field_size_limit(10**9)

input_file = 'AST_Data/temp/train-data.csv'
output_file = 'AST_Data/temp/train-data_whitout_numbers.csv'

with open(input_file, 'r') as file:
    csv_reader = csv.reader(file)
    header = next(csv_reader)  # Read the header

    # Remove the numbers from each row
    cleaned_rows = []
    for row in csv_reader:
        cleaned_row = [
            ''.join([char for char in row[0] if not char.isdigit()]),  # Remove numbers from parsed_smell
            ''.join([char for char in row[1] if not char.isdigit()]),  # Remove numbers from parsed_smell_identifiers
            row[2]  # Keep the message as is
        ]
        cleaned_rows.append(cleaned_row)

    # Save the modified content to the output file
    with open(output_file, 'w', newline='') as file:
        csv_writer = csv.writer(file)
        csv_writer.writerow(header)  # Write the header
        csv_writer.writerows(cleaned_rows)

print(f"The file '{output_file}' has been saved with the numbers removed.")
# Out:
# The file 'AST_Data/temp/train-data_whitout_numbers.csv' has been saved with the numbers removed.

# %%
import csv
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import pickle

input_file = 'AST_Data/temp/train-data_whitout_numbers.csv'

# Read the modified file
df = pd.read_csv(input_file)

# Extract the "message" column values
messages = df['message'].values

# Perform label encoding
encoder = LabelEncoder()
encoded_messages = encoder.fit_transform(messages)

# Update the DataFrame with the encoded values
df_encoded = df.copy()
df_encoded['message_encoded'] = encoded_messages

# Save the encoded content to a new CSV file
output_file = 'AST_Data/temp/train-data_encoded.csv'
df_encoded.to_csv(output_file, index=False)

# Save the encoding vocabulary
vocabulary_file = 'AST_Data/message_encoding_vocabulary.pkl'
with open(vocabulary_file, 'wb') as f:
    pickle.dump(encoder.classes_, f)

print(f"The encoded data has been saved to '{output_file}'.")
print(f"The message encoding vocabulary has been saved to '{vocabulary_file}'.")
# Out:
# The encoded data has been saved to 'AST_Data/temp/train-data_encoded.csv'.
# The message encoding vocabulary has been saved to 'AST_Data/message_encoding_vocabulary.pkl'.
